# %% [markdown]
# #  Consignes
#
# ## Description
#
# Ouvrir le fichier ks-projects-201801.csv, il recense environ 100 000 projets KickStarter. Intégrer les données directement avec L'API Python dans une base de données Mongo.
#
# Il conviendra de bien spécifier manuellement l'ID du document. Pensez aussi à bien formatter le type des données pour profiter des méthodes implémentées par Mongo. L'ensemble de données n'est pas forcément nécessaire, c'est à vous de créer votre modèle de données.
#
# ## Questions
#
# - 1) Récupérer les 5 projets ayant reçu le plus de promesse de dons.
# - 2) Compter le nombre de projets ayant atteint leur but.
# - 3) Compter le nombre de projets pour chaque catégorie.
# - 4) Compter le nombre de projets français ayant été instanciés avant 2016.
# - 5) Récupérer les projets américains ayant demandé plus de 200 000 dollars.
# - 6) Compter le nombre de projet ayant "Sport" dans leur nom

# %%
import pandas as pd
import pymongo

# %%
client = pymongo.MongoClient("mongo")
database = client['exercices']
collection = database['kickstarter']

# %%
df_ks = pd.read_csv("data/ks-projects-201801-sample.csv")
df_ks.head()
# Out:
# /root/.local/share/virtualenvs/code-AFz48Hjb/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (6,8,10,12) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#            ID                                               name  \
# 0   872782264    Scott Cooper's Solo CD "A Leg Trick" (Canceled)
# 1  1326492673                                    Ohceola jewelry
# 2  1688410639  Sluff Off & Harald: Two latest EGGs are Classi...
# 3   156812982  SketchPlanner: Create and Plan- all in one bea...
# 4  1835968190    Proven sales with custom motorcycle accessories
#
#          category main_category currency    deadline   goal  \
# 0            Rock         Music      USD  2011-09-16   2000
# 1         Fashion       Fashion      USD  2012-08-22  18000
# 2  Tabletop Games         Games      USD  2016-07-19   2000
# 3       Art Books    Publishing      USD  2017-09-27  13000
# 4       Sculpture           Art      CAD  2016-02-24   5000
#
#               launched pledged       state backers country usd pledged  \
# 0  2011-08-17 06:31:31    1145    canceled      24      US        1145
# 1  2012-07-23 20:46:48    1851      failed      28      US        1851
# 2  2016-07-01 21:55:54    7534  successful     254      US        3796
# 3  2017-08-28 15:47:02   16298  successful     367      US        2670
# 4  2016-01-25 17:37:10       1      failed       1      CA    0.708148
#
#    usd_pledged_real
# 0       1145.000000
# 1       1851.000000
# 2       7534.000000
# 3      16298.000000
# 4          0.738225

# %% [markdown]
# Ce warning intervient lorsque pandas n'arrive pas à inférer le type de données. Il est sympa il précise les colones 6,8,10,12.

# %%
df_ks.columns[[6,8,10,12]]
# Out:
# Index(['goal', 'pledged', 'backers', 'usd pledged'], dtype='object')

# %% [markdown]
# ## Question 0

# %% [markdown]
# ### Netoyer les données

# %%
df_ks["launched"] = df_ks["launched"].str[:4]

# %%
df_ks = df_ks.drop(columns=['ID', 'currency', 'deadline', 'backers'])

# %%
df_ks.columns
# Out:
# Index(['name', 'category', 'main_category', 'goal', 'launched', 'pledged',
#        'state', 'country', 'usd pledged', 'usd_pledged_real'],
#       dtype='object')

# %%
df_ks = df_ks.rename({"usd pledged":"usd_pledged"}, axis='columns')

# %% [markdown]
# ### Importer les données

# %%
collection.delete_many({})

# %%
df_ks.dtypes
# Out:
# name                 object
# category             object
# main_category        object
# goal                 object
# launched             object
# pledged              object
# state                object
# country              object
# usd_pledged          object
# usd_pledged_real    float64
# dtype: object

# %%
dict = df_ks.to_dict('records')

# %%
collection.insert_many(dict)

# %% [markdown]
# ## question 1

# %%
#prendre les 5 pledged les plus grand
cur = collection.find({"pledged":{"$gte" :30}}).sort([("pledged",-1)]).limit(5)
list(cur)
# Out:
# [{'_id': ObjectId('5fc50686d1f608e348e43cfc'),
#   'name': 'The Everyday Backpack, Tote, and Sling',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'goal': 500000.0,
#   'launched': '2016',
#   'pledged': 6565782.5,
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged': 1462611.0,
#   'usd_pledged_real': 6565782.5},
#  {'_id': ObjectId('5fc50651d1f608e348e2e5ae'),
#   'name': 'Pono Music - Where Your Soul Rediscovers Music',
#   'category': 'Sound',
#   'main_category': 'Technology',
#   'goal': 800000.0,
#   'launched': '2014',
#   'pledged': 6225354.98,
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged': 6225354.98,
#   'usd_pledged_real': 6225354.98},
#  {'_id': ObjectId('5fc50651d1f608e348e2e8e3'),
#   'name': 'The Veronica Mars Movie Project',
#   'category': 'Narrative Film',
#   'main_category': 'Film & Video',
#   'goal': 2000000.0,
#   'launched': '2013',
#   'pledged': 5702153.38,
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged': 5702153.38,
#   'usd_pledged_real': 5702153.38},
#  {'_id': ObjectId('5fc50682d1f608e348e41cb0'),
#   'name': 'Zombicide: Black Plague',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'goal': 125000.0,
#   'launched': '2015',
#   'pledged': 4079204.52,
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged': 4079204.52,
#   'usd_pledged_real': 4079204.52},
#  {'_id': ObjectId('5fc50656d1f608e348e30768'),
#   'name': 'The Dash ï¿½ Wireless Smart In Ear Headphones',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'goal': 260000.0,
#   'launched': '2014',
#   'pledged': 3390551.0,
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged': 3390551.0,
#   'usd_pledged_real': 3390551.0}]

# %% [markdown]
# ## Question 2

# %%
cur = collection.count_documents({"state" : "successful"})
print(cur)
# Out:
# 53040

# %% [markdown]
# ## Question 3

# %%
cur = collection.aggregate([{"$group" : {"_id" : "$category", "NumberByCategory" : {"$sum" : 1}}}])
list(cur)
# Out:
# [{'_id': 'Embroidery', 'NumberByCategory': 49},
#  {'_id': 'Public Art', 'NumberByCategory': 1248},
#  {'_id': 'Flight', 'NumberByCategory': 158},
#  {'_id': 'Rock', 'NumberByCategory': 2707},
#  {'_id': 'Performances', 'NumberByCategory': 414},
#  {'_id': 'Puzzles', 'NumberByCategory': 95},
#  {'_id': 'Audio', 'NumberByCategory': 164},
#  {'_id': 'Gaming Hardware', 'NumberByCategory': 178},
#  {'_id': 'Poetry', 'NumberByCategory': 532},
#  {'_id': 'Theater', 'NumberByCategory': 2786},
#  {'_id': 'Makerspaces', 'NumberByCategory': 91},
#  {'_id': 'Photobooks', 'NumberByCategory': 608},
#  {'_id': 'Family', 'NumberByCategory': 130},
#  {'_id': 'Punk', 'NumberByCategory': 127},
#  {'_id': 'Zines', 'NumberByCategory': 144},
#  {'_id': 'Movie Theaters', 'NumberByCategory': 90},
#  {'_id': 'Publishing', 'NumberByCategory': 2332},
#  {'_id': 'Community Gardens', 'NumberByCategory': 115},
#  {'_id': 'Graphic Design', 'NumberByCategory': 765},
#  {'_id': 'Weaving', 'NumberByCategory': 38},
#  {'_id': 'Action', 'NumberByCategory': 282},
#  {'_id': 'Calendars', 'NumberByCategory': 112},
#  {'_id': 'Interactive Design', 'NumberByCategory': 146},
#  {'_id': 'Country & Folk', 'NumberByCategory': 1790},
#  {'_id': 'Indie Rock', 'NumberByCategory': 2192},
#  {'_id': 'Letterpress', 'NumberByCategory': 24},
#  {'_id': 'Kids', 'NumberByCategory': 109},
#  {'_id': 'Technology', 'NumberByCategory': 2690},
#  {'_id': 'Festivals', 'NumberByCategory': 313},
#  {'_id': 'Fabrication Tools', 'NumberByCategory': 96},
#  {'_id': 'Sound', 'NumberByCategory': 255},
#  {'_id': 'Periodicals', 'NumberByCategory': 517},
#  {'_id': 'Translations', 'NumberByCategory': 76},
#  {'_id': 'Thrillers', 'NumberByCategory': 302},
#  {'_id': 'Academic', 'NumberByCategory': 367},
#  {'_id': 'Wearables', 'NumberByCategory': 508},
#  {'_id': "Farmer's Markets", 'NumberByCategory': 175},
#  {'_id': 'Food', 'NumberByCategory': 4612},
#  {'_id': 'Comics', 'NumberByCategory': 1931},
#  {'_id': 'Video Games', 'NumberByCategory': 4799},
#  {'_id': 'Animals', 'NumberByCategory': 97},
#  {'_id': 'Performance Art', 'NumberByCategory': 855},
#  {'_id': 'Pop', 'NumberByCategory': 1302},
#  {'_id': 'DIY Electronics', 'NumberByCategory': 358},
#  {'_id': 'Drama', 'NumberByCategory': 871},
#  {'_id': 'Graphic Novels', 'NumberByCategory': 702},
#  {'_id': 'Musical', 'NumberByCategory': 367},
#  {'_id': 'Dance', 'NumberByCategory': 901},
#  {'_id': 'Immersive', 'NumberByCategory': 131},
#  {'_id': 'Animation', 'NumberByCategory': 1017},
#  {'_id': 'Nature', 'NumberByCategory': 219},
#  {'_id': 'Drinks', 'NumberByCategory': 995},
#  {'_id': 'Documentary', 'NumberByCategory': 6498},
#  {'_id': 'Photo', 'NumberByCategory': 58},
#  {'_id': 'Jazz', 'NumberByCategory': 733},
#  {'_id': 'Comic Books', 'NumberByCategory': 1032},
#  {'_id': 'Faith', 'NumberByCategory': 439},
#  {'_id': 'Television', 'NumberByCategory': 401},
#  {'_id': 'Ceramics', 'NumberByCategory': 128},
#  {'_id': 'Apps', 'NumberByCategory': 2535},
#  {'_id': 'Quilts', 'NumberByCategory': 32},
#  {'_id': 'Fantasy', 'NumberByCategory': 132},
#  {'_id': 'Robots', 'NumberByCategory': 237},
#  {'_id': 'Glass', 'NumberByCategory': 51},
#  {'_id': 'Taxidermy', 'NumberByCategory': 7},
#  {'_id': 'Games', 'NumberByCategory': 1331},
#  {'_id': 'Mobile Games', 'NumberByCategory': 650},
#  {'_id': "Children's Books", 'NumberByCategory': 2686},
#  {'_id': 'Narrative Film', 'NumberByCategory': 2099},
#  {'_id': 'Chiptune', 'NumberByCategory': 10},
#  {'_id': 'Jewelry', 'NumberByCategory': 472},
#  {'_id': '3D Printing', 'NumberByCategory': 271},
#  {'_id': 'Typography', 'NumberByCategory': 44},
#  {'_id': 'Live Games', 'NumberByCategory': 394},
#  {'_id': 'Food Trucks', 'NumberByCategory': 687},
#  {'_id': 'Literary Spaces', 'NumberByCategory': 10},
#  {'_id': 'R&B', 'NumberByCategory': 172},
#  {'_id': 'Romance', 'NumberByCategory': 74},
#  {'_id': 'Stationery', 'NumberByCategory': 90},
#  {'_id': 'Art', 'NumberByCategory': 3358},
#  {'_id': 'Fine Art', 'NumberByCategory': 291},
#  {'_id': 'Mixed Media', 'NumberByCategory': 1118},
#  {'_id': 'Video Art', 'NumberByCategory': 65},
#  {'_id': 'Camera Equipment', 'NumberByCategory': 165},
#  {'_id': 'Architecture', 'NumberByCategory': 300},
#  {'_id': 'Metal', 'NumberByCategory': 274},
#  {'_id': 'Webseries', 'NumberByCategory': 2316},
#  {'_id': 'Journalism', 'NumberByCategory': 672},
#  {'_id': 'DIY', 'NumberByCategory': 480},
#  {'_id': 'Events', 'NumberByCategory': 322},
#  {'_id': 'Latin', 'NumberByCategory': 63},
#  {'_id': 'Childrenswear', 'NumberByCategory': 192},
#  {'_id': 'Sculpture', 'NumberByCategory': 737},
#  {'_id': 'Accessories', 'NumberByCategory': 1204},
#  {'_id': 'Shorts', 'NumberByCategory': 4857},
#  {'_id': 'Classical Music', 'NumberByCategory': 1064},
#  {'_id': 'Literary Journals', 'NumberByCategory': 118},
#  {'_id': 'Product Design', 'NumberByCategory': 8886},
#  {'_id': 'Space Exploration', 'NumberByCategory': 137},
#  {'_id': 'Crafts', 'NumberByCategory': 1834},
#  {'_id': 'Plays', 'NumberByCategory': 539},
#  {'_id': 'Horror', 'NumberByCategory': 525},
#  {'_id': 'Printing', 'NumberByCategory': 83},
#  {'_id': 'Couture', 'NumberByCategory': 108},
#  {'_id': 'Design', 'NumberByCategory': 1641},
#  {'_id': 'World Music', 'NumberByCategory': 850},
#  {'_id': 'Illustration', 'NumberByCategory': 1263},
#  {'_id': 'Hip-Hop', 'NumberByCategory': 1555},
#  {'_id': 'Cookbooks', 'NumberByCategory': 217},
#  {'_id': 'Installations', 'NumberByCategory': 178},
#  {'_id': 'Digital Art', 'NumberByCategory': 524},
#  {'_id': 'Pet Fashion', 'NumberByCategory': 51},
#  {'_id': 'Places', 'NumberByCategory': 283},
#  {'_id': 'Workshops', 'NumberByCategory': 59},
#  {'_id': 'Blues', 'NumberByCategory': 113},
#  {'_id': 'Bacon', 'NumberByCategory': 78},
#  {'_id': 'Farms', 'NumberByCategory': 482},
#  {'_id': 'Gadgets', 'NumberByCategory': 1210},
#  {'_id': 'Web', 'NumberByCategory': 2017},
#  {'_id': 'Candles', 'NumberByCategory': 168},
#  {'_id': 'Apparel', 'NumberByCategory': 2827},
#  {'_id': 'Vegan', 'NumberByCategory': 229},
#  {'_id': 'Music', 'NumberByCategory': 6229},
#  {'_id': 'Spaces', 'NumberByCategory': 331},
#  {'_id': 'Comedy', 'NumberByCategory': 923},
#  {'_id': 'Fiction', 'NumberByCategory': 3703},
#  {'_id': 'Ready-to-wear', 'NumberByCategory': 332},
#  {'_id': 'Film & Video', 'NumberByCategory': 4003},
#  {'_id': 'Science Fiction', 'NumberByCategory': 274},
#  {'_id': 'Electronic Music', 'NumberByCategory': 858},
#  {'_id': 'Print', 'NumberByCategory': 288},
#  {'_id': 'People', 'NumberByCategory': 440},
#  {'_id': 'Painting', 'NumberByCategory': 1288},
#  {'_id': 'Civic Design', 'NumberByCategory': 130},
#  {'_id': 'Woodworking', 'NumberByCategory': 433},
#  {'_id': 'Software', 'NumberByCategory': 1194},
#  {'_id': 'Art Books', 'NumberByCategory': 1065},
#  {'_id': 'Anthologies', 'NumberByCategory': 300},
#  {'_id': 'Webcomics', 'NumberByCategory': 259},
#  {'_id': 'Music Videos', 'NumberByCategory': 299},
#  {'_id': 'Experimental', 'NumberByCategory': 357},
#  {'_id': 'Fashion', 'NumberByCategory': 3379},
#  {'_id': 'Conceptual Art', 'NumberByCategory': 393},
#  {'_id': 'Textiles', 'NumberByCategory': 105},
#  {'_id': 'Residencies', 'NumberByCategory': 32},
#  {'_id': 'Radio & Podcasts', 'NumberByCategory': 349},
#  {'_id': 'Playing Cards', 'NumberByCategory': 963},
#  {'_id': 'Hardware', 'NumberByCategory': 1431},
#  {'_id': 'Restaurants', 'NumberByCategory': 1089},
#  {'_id': 'Video', 'NumberByCategory': 147},
#  {'_id': 'Pottery', 'NumberByCategory': 40},
#  {'_id': 'Tabletop Games', 'NumberByCategory': 5581},
#  {'_id': 'Nonfiction', 'NumberByCategory': 3390},
#  {'_id': 'Photography', 'NumberByCategory': 2239},
#  {'_id': 'Grace is Leaving', 'NumberByCategory': 1},
#  {'_id': 'Knitting', 'NumberByCategory': 78},
#  {'_id': 'Crochet', 'NumberByCategory': 61},
#  {'_id': 'Footwear', 'NumberByCategory': 379},
#  {'_id': 'Small Batch', 'NumberByCategory': 701},
#  {'_id': 'Young Adult', 'NumberByCategory': 328}]

# %% [markdown]
# ## Question 4

# %%
#I did it by counting all the element after extracting the wanted element
cur = collection.count_documents({"$and":[{"launched":{"$lt": "2016"}}, {"country":"FR"}]})
print(cur)
# Out:
# 330

# %% [markdown]
# ## Question 5

# %%
cur = collection.find({"$and":[{"goal":{"$gte": 200000}}, {"country":"US"}]})
list(cur)
# Out:
# [{'_id': ObjectId('5fc50631d1f608e348e20a9b'),
#   'name': 'Far from Par is a movie about a man and a talking golf ball.',
#   'category': 'Comedy',
#   'main_category': 'Film & Video',
#   'goal': 200000.0,
#   'launched': '2014',
#   'pledged': 10.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 10.0,
#   'usd_pledged_real': 10.0},
#  {'_id': ObjectId('5fc50631d1f608e348e20aae'),
#   'name': 'A CALL TO ADVENTURE',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'goal': 287000.0,
#   'launched': '2012',
#   'pledged': 1465.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 1465.0,
#   'usd_pledged_real': 1465.0},
#  {'_id': ObjectId('5fc50632d1f608e348e20b61'),
#   'name': 'Storybricks, the storytelling online RPG',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'goal': 250000.0,
#   'launched': '2012',
#   'pledged': 23680.54,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 23680.54,
#   'usd_pledged_real': 23680.54},
#  {'_id': ObjectId('5fc50632d1f608e348e20b69'),
#   'name': 'Shine On New World',
#   'category': 'Theater',
#   'main_category': 'Theater',
#   'goal': 300000.0,
#   'launched': '2013',
#   'pledged': 12314.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 12314.0,
#   'usd_pledged_real': 12314.0},
#  {'_id': ObjectId('5fc50632d1f608e348e20b78'),
#   'name': 'Nightclub',
#   'category': 'Music',
#   'main_category': 'Music',
#   'goal': 3000000.0,
#   'launched': '2017',
#   'pledged': 1.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 1.0},
#  {'_id': ObjectId('5fc50632d1f608e348e20cfc'),
#   'name': 'Nastaran (Wild Rose)',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'goal': 250000.0,
#   'launched': '2015',
#   'pledged': 0.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc50632d1f608e348e20d03'),
#   'name': 'Hubo - Extension Box for iPhone',
#   'category': 'Gadgets',
#   'main_category': 'Technology',
#   'goal': 250000.0,
#   'launched': '2016',
#   'pledged': 1996.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 438.0,
#   'usd_pledged_real': 1996.0},
#  {'_id': ObjectId('5fc50632d1f608e348e20d22'),
#   'name': 'Baja ATV Park (Suspended)',
#   'category': 'Live Games',
#   'main_category': 'Games',
#   'goal': 300000.0,
#   'launched': '2016',
#   'pledged': 11.0,
#   'state': 'suspended',
#   'country': 'US',
#   'usd_pledged': 11.0,
#   'usd_pledged_real': 11.0},
#  {'_id': ObjectId('5fc50632d1f608e348e20d40'),
#   'name': 'Chihuly Installation for Orlando (Pulse Nightclub)',
#   'category': 'Installations',
#   'main_category': 'Art',
#   'goal': 1000000.0,
#   'launched': '2016',
#   'pledged': 5.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 4.0,
#   'usd_pledged_real': 5.0},
#  {'_id': ObjectId('5fc50632d1f608e348e20e05'),
#   'name': 'Kurt Vonnegut: Unstuck in Time',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'goal': 250000.0,
#   'launched': '2015',
#   'pledged': 300319.0,
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged': 300319.0,
#   'usd_pledged_real': 300319.0},
#  {'_id': ObjectId('5fc50632d1f608e348e20e54'),
#   'name': 'The LAKE HOPPER is a VTOL Flying Water Craft Made in America',
#   'category': 'Flight',
#   'main_category': 'Technology',
#   'goal': 3000000.0,
#   'launched': '2016',
#   'pledged': 0.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc50632d1f608e348e20e88'),
#   'name': '"Hill" (11 For 11) (From the writer of Rudy & Hoosiers)',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'goal': 1000000.0,
#   'launched': '2012',
#   'pledged': 0.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc50632d1f608e348e20eaf'),
#   'name': 'Saints of The Classroom',
#   'category': 'Television',
#   'main_category': 'Film & Video',
#   'goal': 250000.0,
#   'launched': '2016',
#   'pledged': 3085.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 1915.0,
#   'usd_pledged_real': 3085.0},
#  {'_id': ObjectId('5fc50632d1f608e348e20f47'),
#   'name': 'Hemingwrite - A Distraction Free Digital Typewriter',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'goal': 250000.0,
#   'launched': '2014',
#   'pledged': 342471.0,
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged': 342471.0,
#   'usd_pledged_real': 342471.0},
#  {'_id': ObjectId('5fc50632d1f608e348e20f8a'),
#   'name': 'Breakfast 24/7',
#   'category': 'Food',
#   'main_category': 'Food',
#   'goal': 1000000.0,
#   'launched': '2016',
#   'pledged': 0.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc50632d1f608e348e20fb6'),
#   'name': 'FJE REVOLT',
#   'category': 'Apparel',
#   'main_category': 'Fashion',
#   'goal': 500000.0,
#   'launched': '2015',
#   'pledged': 0.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc50632d1f608e348e20fb7'),
#   'name': 'Austin City Limits 40 Year History Documentary Film',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'goal': 400000.0,
#   'launched': '2014',
#   'pledged': 9.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 9.0,
#   'usd_pledged_real': 9.0},
#  {'_id': ObjectId('5fc50632d1f608e348e21005'),
#   'name': 'Ozark Mountain Ranch',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'goal': 466000.0,
#   'launched': '2015',
#   'pledged': 1076.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 1076.0,
#   'usd_pledged_real': 1076.0},
#  {'_id': ObjectId('5fc50632d1f608e348e21010'),
#   'name': 'STEM Lesson Plan - BotBrainï¿½ Educational Products',
#   'category': 'Software',
#   'main_category': 'Technology',
#   'goal': 279646.0,
#   'launched': '2014',
#   'pledged': 85.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 85.0,
#   'usd_pledged_real': 85.0},
#  {'_id': ObjectId('5fc50632d1f608e348e21029'),
#   'name': 'Guitar Godz VR: A 3D Rock Music Game',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'goal': 500000.0,
#   'launched': '2017',
#   'pledged': 22612.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 12311.0,
#   'usd_pledged_real': 22612.0},
#  {'_id': ObjectId('5fc50632d1f608e348e2106e'),
#   'name': "The world's first crowd funded millionaire documentary",
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'goal': 1000000.0,
#   'launched': '2015',
#   'pledged': 171.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 171.0,
#   'usd_pledged_real': 171.0},
#  {'_id': ObjectId('5fc50632d1f608e348e210d3'),
#   'name': 'Creating an online game, "Perdition Online".',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'goal': 350000.0,
#   'launched': '2013',
#   'pledged': 16.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 16.0,
#   'usd_pledged_real': 16.0},
#  {'_id': ObjectId('5fc50632d1f608e348e21135'),
#   'name': 'The Adventures of Billy Buskirk',
#   'category': 'Family',
#   'main_category': 'Film & Video',
#   'goal': 750000.0,
#   'launched': '2017',
#   'pledged': 1.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 1.0,
#   'usd_pledged_real': 1.0},
#  {'_id': ObjectId('5fc50632d1f608e348e21212'),
#   'name': 'MY TINSEL TOWN (Canceled)',
#   'category': 'Apps',
#   'main_category': 'Technology',
#   'goal': 577000.0,
#   'launched': '2014',
#   'pledged': 0.0,
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc50632d1f608e348e2121d'),
#   'name': 'Moonlight 5 star (Canceled)',
#   'category': 'Restaurants',
#   'main_category': 'Food',
#   'goal': 250000.0,
#   'launched': '2016',
#   'pledged': 0.0,
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc50632d1f608e348e21279'),
#   'name': 'TOMB Adventure 2',
#   'category': 'Games',
#   'main_category': 'Games',
#   'goal': 200000.0,
#   'launched': '2012',
#   'pledged': 5740.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 5740.0,
#   'usd_pledged_real': 5740.0},
#  {'_id': ObjectId('5fc50632d1f608e348e212af'),
#   'name': 'The EIFLE S Smart-Mirror W/Front-Facing Camera! (Canceled)',
#   'category': 'Software',
#   'main_category': 'Technology',
#   'goal': 200000.0,
#   'launched': '2016',
#   'pledged': 4248.0,
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged': 4248.0,
#   'usd_pledged_real': 4248.0},
#  {'_id': ObjectId('5fc50632d1f608e348e212be'),
#   'name': 'The Brick Cafe',
#   'category': 'Food',
#   'main_category': 'Food',
#   'goal': 200000.0,
#   'launched': '2016',
#   'pledged': 0.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc50633d1f608e348e21317'),
#   'name': 'Dangerous Seas: A Beautiful Under Water War App (Canceled)',
#   'category': 'Mobile Games',
#   'main_category': 'Games',
#   'goal': 400000.0,
#   'launched': '2016',
#   'pledged': 146.0,
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged': 146.0,
#   'usd_pledged_real': 146.0},
#  {'_id': ObjectId('5fc50633d1f608e348e21340'),
#   'name': 'ViewCoze.com | Cozy viewing from home (Canceled)',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'goal': 370000.0,
#   'launched': '2015',
#   'pledged': 80.0,
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged': 80.0,
#   'usd_pledged_real': 80.0},
#  {'_id': ObjectId('5fc50633d1f608e348e2134d'),
#   'name': 'Meet kubo: an electric scooter to carry all your stuff!',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'goal': 300000.0,
#   'launched': '2013',
#   'pledged': 56667.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 56667.0,
#   'usd_pledged_real': 56667.0},
#  {'_id': ObjectId('5fc50633d1f608e348e21374'),
#   'name': 'ONEIDNET Social Professional Commercial Corporate Platform',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'goal': 545539.0,
#   'launched': '2017',
#   'pledged': 1.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 1.0},
#  {'_id': ObjectId('5fc50633d1f608e348e213a2'),
#   'name': 'Civilian Cam',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'goal': 200000.0,
#   'launched': '2015',
#   'pledged': 10.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 10.0,
#   'usd_pledged_real': 10.0},
#  {'_id': ObjectId('5fc50633d1f608e348e213e5'),
#   'name': 'The Scariest Movie Ever Created',
#   'category': 'Horror',
#   'main_category': 'Film & Video',
#   'goal': 100000000.0,
#   'launched': '2015',
#   'pledged': 1.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 1.0,
#   'usd_pledged_real': 1.0},
#  {'_id': ObjectId('5fc50633d1f608e348e214e0'),
#   'name': 'The SEED Project',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'goal': 250000.0,
#   'launched': '2012',
#   'pledged': 35.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 35.0,
#   'usd_pledged_real': 35.0},
#  {'_id': ObjectId('5fc50633d1f608e348e214fa'),
#   'name': 'NewsRadio Season 6 (Canceled)',
#   'category': 'Television',
#   'main_category': 'Film & Video',
#   'goal': 3000000.0,
#   'launched': '2015',
#   'pledged': 101.0,
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged': 101.0,
#   'usd_pledged_real': 101.0},
#  {'_id': ObjectId('5fc50633d1f608e348e21540'),
#   'name': 'Get Me Me Kids (Books, Music, Film & Games)',
#   'category': "Children's Books",
#   'main_category': 'Publishing',
#   'goal': 500000.0,
#   'launched': '2015',
#   'pledged': 0.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc50633d1f608e348e215c0'),
#   'name': "Daniel's Dream",
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'goal': 2000000.0,
#   'launched': '2013',
#   'pledged': 60.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 60.0,
#   'usd_pledged_real': 60.0},
#  {'_id': ObjectId('5fc50633d1f608e348e215ee'),
#   'name': 'iFly Hand Held Camera Crane- pan AND tilt - iPhone GoPro etc',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'goal': 444000.0,
#   'launched': '2012',
#   'pledged': 3439.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 3439.0,
#   'usd_pledged_real': 3439.0},
#  {'_id': ObjectId('5fc50633d1f608e348e2162d'),
#   'name': 'GolferVox',
#   'category': 'Apps',
#   'main_category': 'Technology',
#   'goal': 1200000.0,
#   'launched': '2015',
#   'pledged': 70.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 70.0,
#   'usd_pledged_real': 70.0},
#  {'_id': ObjectId('5fc50633d1f608e348e21654'),
#   'name': 'Power Rangers | fan film reboot movie',
#   'category': 'Action',
#   'main_category': 'Film & Video',
#   'goal': 400000.0,
#   'launched': '2015',
#   'pledged': 0.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc50633d1f608e348e21729'),
#   'name': '"Another Network" Film Project',
#   'category': 'Narrative Film',
#   'main_category': 'Film & Video',
#   'goal': 225000.0,
#   'launched': '2014',
#   'pledged': 55.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 55.0,
#   'usd_pledged_real': 55.0},
#  {'_id': ObjectId('5fc50633d1f608e348e217ea'),
#   'name': 'SELF-SUSTAINING ORGANIC FARM',
#   'category': 'Farms',
#   'main_category': 'Food',
#   'goal': 450000.0,
#   'launched': '2014',
#   'pledged': 11.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 11.0,
#   'usd_pledged_real': 11.0},
#  {'_id': ObjectId('5fc50633d1f608e348e217f0'),
#   'name': 'Fuel-X-Tender',
#   'category': 'Gadgets',
#   'main_category': 'Technology',
#   'goal': 500000.0,
#   'launched': '2014',
#   'pledged': 272.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 272.0,
#   'usd_pledged_real': 272.0},
#  {'_id': ObjectId('5fc50633d1f608e348e21805'),
#   'name': 'Salad Barr ( the new fast food restaurant )',
#   'category': 'Restaurants',
#   'main_category': 'Food',
#   'goal': 270000.0,
#   'launched': '2016',
#   'pledged': 1.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 1.0,
#   'usd_pledged_real': 1.0},
#  {'_id': ObjectId('5fc50633d1f608e348e2180d'),
#   'name': 'We want your money (Suspended)',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'goal': 300000.0,
#   'launched': '2016',
#   'pledged': 123.0,
#   'state': 'suspended',
#   'country': 'US',
#   'usd_pledged': 123.0,
#   'usd_pledged_real': 123.0},
#  {'_id': ObjectId('5fc50633d1f608e348e2186a'),
#   'name': "Dutch's Kegs",
#   'category': 'Small Batch',
#   'main_category': 'Food',
#   'goal': 1000000.0,
#   'launched': '2015',
#   'pledged': 260.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 260.0,
#   'usd_pledged_real': 260.0},
#  {'_id': ObjectId('5fc50633d1f608e348e21891'),
#   'name': 'Pro Tailgater Party Plate',
#   'category': 'Gadgets',
#   'main_category': 'Technology',
#   'goal': 365000.0,
#   'launched': '2017',
#   'pledged': 200.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 200.0},
#  {'_id': ObjectId('5fc50633d1f608e348e2189b'),
#   'name': 'Gabriel Device - Free energy for everyone',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'goal': 500000.0,
#   'launched': '2017',
#   'pledged': 81.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 40.0,
#   'usd_pledged_real': 81.0},
#  {'_id': ObjectId('5fc50633d1f608e348e218d3'),
#   'name': 'Pallet Wars, Part 1...Two More Weeks and Billions Are Ours!!',
#   'category': 'Narrative Film',
#   'main_category': 'Film & Video',
#   'goal': 875000.0,
#   'launched': '2017',
#   'pledged': 5.0,
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 5.0},
#  {'_id': ObjectId('5fc50633d1f608e348e2193b'),
#   'name': 'Fast Easy Lightweight Modular Cabinets PhastPhurniture',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'goal': 250000.0,
#   'launched': '2017',
#   'pledged': 710.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 200.0,
#   'usd_pledged_real': 710.0},
#  {'_id': ObjectId('5fc50633d1f608e348e21981'),
#   'name': 'Sonic Chao World fan game (Canceled)',
#   'category': 'Games',
#   'main_category': 'Games',
#   'goal': 1000000.0,
#   'launched': '2015',
#   'pledged': 0.0,
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc50634d1f608e348e219bc'),
#   'name': 'StreamStick: The Future of Streaming TV and Media (Canceled)',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'goal': 200000.0,
#   'launched': '2015',
#   'pledged': 4433.0,
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged': 4433.0,
#   'usd_pledged_real': 4433.0},
#  {'_id': ObjectId('5fc50634d1f608e348e219ff'),
#   'name': 'The Darkest Dawn',
#   'category': 'Narrative Film',
#   'main_category': 'Film & Video',
#   'goal': 500000.0,
#   'launched': '2013',
#   'pledged': 5.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 5.0,
#   'usd_pledged_real': 5.0},
#  {'_id': ObjectId('5fc50634d1f608e348e21aa6'),
#   'name': 'Adventure Combat Ops - A real life, apocalyptic video game!',
#   'category': 'Live Games',
#   'main_category': 'Games',
#   'goal': 400000.0,
#   'launched': '2014',
#   'pledged': 320.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 320.0,
#   'usd_pledged_real': 320.0},
#  {'_id': ObjectId('5fc50634d1f608e348e21ab4'),
#   'name': 'Haboob Wind - The Movie',
#   'category': 'Drama',
#   'main_category': 'Film & Video',
#   'goal': 200000.0,
#   'launched': '2017',
#   'pledged': 125.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 100.0,
#   'usd_pledged_real': 125.0},
#  {'_id': ObjectId('5fc50634d1f608e348e21ae4'),
#   'name': "World's First Smart Football",
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'goal': 500000.0,
#   'launched': '2015',
#   'pledged': 1.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 1.0,
#   'usd_pledged_real': 1.0},
#  {'_id': ObjectId('5fc50634d1f608e348e21b2b'),
#   'name': 'The Maryanne Godboldo Story (Canceled)',
#   'category': 'Narrative Film',
#   'main_category': 'Film & Video',
#   'goal': 250000.0,
#   'launched': '2013',
#   'pledged': 2350.0,
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged': 2350.0,
#   'usd_pledged_real': 2350.0},
#  {'_id': ObjectId('5fc50634d1f608e348e21b55'),
#   'name': 'M.A.C.S. (Canceled)',
#   'category': 'Space Exploration',
#   'main_category': 'Technology',
#   'goal': 400000.0,
#   'launched': '2014',
#   'pledged': 8.0,
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged': 8.0,
#   'usd_pledged_real': 8.0},
#  {'_id': ObjectId('5fc50634d1f608e348e21b74'),
#   'name': 'Keeping my best friends dream alive after losing to cancer',
#   'category': 'DIY',
#   'main_category': 'Crafts',
#   'goal': 200000.0,
#   'launched': '2014',
#   'pledged': 5.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 5.0,
#   'usd_pledged_real': 5.0},
#  {'_id': ObjectId('5fc50634d1f608e348e21ba7'),
#   'name': 'Planetary Annihilation - A Next Generation RTS',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'goal': 900000.0,
#   'launched': '2012',
#   'pledged': 2229344.36,
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged': 2229344.36,
#   'usd_pledged_real': 2229344.36},
#  {'_id': ObjectId('5fc50634d1f608e348e21ba9'),
#   'name': "Pontruff's Pop Shop, Pizza, and Punk Rock",
#   'category': 'Restaurants',
#   'main_category': 'Food',
#   'goal': 500000.0,
#   'launched': '2014',
#   'pledged': 0.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc50634d1f608e348e21c71'),
#   'name': 'The Good Fight of Faith',
#   'category': 'Family',
#   'main_category': 'Film & Video',
#   'goal': 1000000.0,
#   'launched': '2015',
#   'pledged': 0.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc50634d1f608e348e21c9d'),
#   'name': 'Film Adaptation of "The Traveler"',
#   'category': 'Narrative Film',
#   'main_category': 'Film & Video',
#   'goal': 1000000.0,
#   'launched': '2016',
#   'pledged': 25.0,
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 25.0},
#  {'_id': ObjectId('5fc50634d1f608e348e21d57'),
#   'name': 'Boulder Creek Brewery and Cafe Rebuild (Canceled)',
#   'category': 'Restaurants',
#   'main_category': 'Food',
#   'goal': 200000.0,
#   'launched': '2015',
#   'pledged': 12397.0,
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged': 12397.0,
#   'usd_pledged_real': 12397.0},
#  {'_id': ObjectId('5fc50634d1f608e348e21d7f'),
#   'name': 'Uncommon Wealth',
#   'category': 'Narrative Film',
#   'main_category': 'Film & Video',
#   'goal': 250000.0,
#   'launched': '2013',
#   'pledged': 2110.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 2110.0,
#   'usd_pledged_real': 2110.0},
#  {'_id': ObjectId('5fc50634d1f608e348e21d8f'),
#   'name': 'Design the Starship Enterprise Science Research Mock Up',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'goal': 313550.0,
#   'launched': '2013',
#   'pledged': 31.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 31.0,
#   'usd_pledged_real': 31.0},
#  {'_id': ObjectId('5fc50634d1f608e348e21df1'),
#   'name': 'Backyard Soccer Buddy / Football Mate (Overseas)',
#   'category': 'Gadgets',
#   'main_category': 'Technology',
#   'goal': 2000000.0,
#   'launched': '2016',
#   'pledged': 0.0,
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc50634d1f608e348e21df7'),
#   'name': 'Frickin! Fleasï¿½ Mobile Game',
#   'category': 'Mobile Games',
#   'main_category': 'Games',
#   'goal': 200000.0,
#   'launched': '2017',
#   'pledged': 353.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 250.0,
#   'usd_pledged_real': 353.0},
#  {'_id': ObjectId('5fc50634d1f608e348e21e41'),
#   'name': '"anonymous (street meat)" (Canceled)',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'goal': 1000000.0,
#   'launched': '2012',
#   'pledged': 0.0,
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc50634d1f608e348e21e5d'),
#   'name': 'Better Days',
#   'category': 'Narrative Film',
#   'main_category': 'Film & Video',
#   'goal': 200000.0,
#   'launched': '2010',
#   'pledged': 50.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 50.0,
#   'usd_pledged_real': 50.0},
#  {'_id': ObjectId('5fc50634d1f608e348e21e8a'),
#   'name': 'Akaneiro: Demon Hunters',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'goal': 200000.0,
#   'launched': '2013',
#   'pledged': 204680.93,
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged': 204680.93,
#   'usd_pledged_real': 204680.93},
#  {'_id': ObjectId('5fc50634d1f608e348e21f45'),
#   'name': 'Hello Space Boy!',
#   'category': 'Animation',
#   'main_category': 'Film & Video',
#   'goal': 2000000.0,
#   'launched': '2016',
#   'pledged': 0.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc50634d1f608e348e21f67'),
#   'name': 'Interactive Breastfeeding Documentary',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'goal': 210000.0,
#   'launched': '2011',
#   'pledged': 12058.3,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 12058.3,
#   'usd_pledged_real': 12058.3},
#  {'_id': ObjectId('5fc50634d1f608e348e21f73'),
#   'name': 'Aquaponics system for supplying fresh organic food.',
#   'category': 'Farms',
#   'main_category': 'Food',
#   'goal': 8000000.0,
#   'launched': '2016',
#   'pledged': 21.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 21.0,
#   'usd_pledged_real': 21.0},
#  {'_id': ObjectId('5fc50634d1f608e348e21fc3'),
#   'name': 'After Reset RPG',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'goal': 900000.0,
#   'launched': '2013',
#   'pledged': 47939.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 47939.0,
#   'usd_pledged_real': 47939.0},
#  {'_id': ObjectId('5fc50634d1f608e348e21ffa'),
#   'name': 'SLAYING GIANTS #GOLIATH',
#   'category': 'Movie Theaters',
#   'main_category': 'Film & Video',
#   'goal': 350000.0,
#   'launched': '2016',
#   'pledged': 2508.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 175.0,
#   'usd_pledged_real': 2508.0},
#  {'_id': ObjectId('5fc50634d1f608e348e22023'),
#   'name': 'Fan News',
#   'category': 'Journalism',
#   'main_category': 'Journalism',
#   'goal': 275000.0,
#   'launched': '2015',
#   'pledged': 10.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 10.0,
#   'usd_pledged_real': 10.0},
#  {'_id': ObjectId('5fc50634d1f608e348e22046'),
#   'name': '*FLASHLIFE* Most Complete Emergency Survival Product Ever.',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'goal': 350000.0,
#   'launched': '2016',
#   'pledged': 1865.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 1.0,
#   'usd_pledged_real': 1865.0},
#  {'_id': ObjectId('5fc50635d1f608e348e220ae'),
#   'name': "Iota: Never lose sight of what's important.",
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'goal': 250000.0,
#   'launched': '2014',
#   'pledged': 282155.0,
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged': 282155.0,
#   'usd_pledged_real': 282155.0},
#  {'_id': ObjectId('5fc50635d1f608e348e2211d'),
#   'name': 'RHN - THE REAL HIP-HOP NETWORK TV CHANNEL  DOCUMENTARY',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'goal': 2000000.0,
#   'launched': '2014',
#   'pledged': 225.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 225.0,
#   'usd_pledged_real': 225.0},
#  {'_id': ObjectId('5fc50635d1f608e348e22126'),
#   'name': 'LAN Center',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'goal': 200000.0,
#   'launched': '2014',
#   'pledged': 2.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 2.0,
#   'usd_pledged_real': 2.0},
#  {'_id': ObjectId('5fc50635d1f608e348e22127'),
#   'name': 'jfg76tukv u',
#   'category': 'Art',
#   'main_category': 'Art',
#   'goal': 250000.0,
#   'launched': '2015',
#   'pledged': 2.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 2.0,
#   'usd_pledged_real': 2.0},
#  {'_id': ObjectId('5fc50635d1f608e348e22145'),
#   'name': 'Shaft in Asia Featured Film',
#   'category': 'Action',
#   'main_category': 'Film & Video',
#   'goal': 1000000.0,
#   'launched': '2015',
#   'pledged': 0.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc50635d1f608e348e2216f'),
#   'name': 'P.U.R.E. Gamers',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'goal': 500000.0,
#   'launched': '2015',
#   'pledged': 25.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 25.0,
#   'usd_pledged_real': 25.0},
#  {'_id': ObjectId('5fc50635d1f608e348e221c7'),
#   'name': 'The Hawaiian Girl Art Studio (Canceled)',
#   'category': 'Digital Art',
#   'main_category': 'Art',
#   'goal': 1100000.0,
#   'launched': '2016',
#   'pledged': 0.0,
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc50635d1f608e348e2224d'),
#   'name': 'The Rock Bar - Mobile Bar/Event Platform',
#   'category': 'Events',
#   'main_category': 'Food',
#   'goal': 200000.0,
#   'launched': '2015',
#   'pledged': 0.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc50635d1f608e348e2235b'),
#   'name': 'The Wager',
#   'category': 'Action',
#   'main_category': 'Film & Video',
#   'goal': 200000.0,
#   'launched': '2015',
#   'pledged': 10.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 10.0,
#   'usd_pledged_real': 10.0},
#  {'_id': ObjectId('5fc50635d1f608e348e2239c'),
#   'name': 'xFaire: A TV Device. Watch Any Content, Anytime & Anywhere',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'goal': 200000.0,
#   'launched': '2016',
#   'pledged': 3523.0,
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged': 3227.0,
#   'usd_pledged_real': 3523.0},
#  {'_id': ObjectId('5fc50635d1f608e348e223cc'),
#   'name': 'Independent Broadcasting Company',
#   'category': 'Television',
#   'main_category': 'Film & Video',
#   'goal': 700000.0,
#   'launched': '2017',
#   'pledged': 56.0,
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged': 56.0,
#   'usd_pledged_real': 56.0},
#  {'_id': ObjectId('5fc50635d1f608e348e2242a'),
#   'name': 'Forbidden Woods (Canceled)',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'goal': 2300000.0,
#   'launched': '2012',
#   'pledged': 0.0,
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc50635d1f608e348e2246b'),
#   'name': "Max and Rex's Adventure",
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'goal': 200000.0,
#   'launched': '2012',
#   'pledged': 4286.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 4286.0,
#   'usd_pledged_real': 4286.0},
#  {'_id': ObjectId('5fc50635d1f608e348e22491'),
#   'name': 'The Guilt Free Life',
#   'category': 'Restaurants',
#   'main_category': 'Food',
#   'goal': 250000.0,
#   'launched': '2014',
#   'pledged': 20.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 20.0,
#   'usd_pledged_real': 20.0},
#  {'_id': ObjectId('5fc50635d1f608e348e22499'),
#   'name': 'Mayacama Chocolate-Bean-to-Bar Craft Chocolate, Napa,Ca',
#   'category': 'Small Batch',
#   'main_category': 'Food',
#   'goal': 780000.0,
#   'launched': '2015',
#   'pledged': 267.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 267.0,
#   'usd_pledged_real': 267.0},
#  {'_id': ObjectId('5fc50635d1f608e348e224a7'),
#   'name': 'Puzzle Camp',
#   'category': 'Games',
#   'main_category': 'Games',
#   'goal': 750000.0,
#   'launched': '2014',
#   'pledged': 35.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 35.0,
#   'usd_pledged_real': 35.0},
#  {'_id': ObjectId('5fc50635d1f608e348e224aa'),
#   'name': 'Vehroot Shelf | Use Your Phone or Tablet as Your Car Stereo',
#   'category': 'Sound',
#   'main_category': 'Technology',
#   'goal': 500000.0,
#   'launched': '2017',
#   'pledged': 5651.0,
#   'state': 'live',
#   'country': 'US',
#   'usd_pledged': 1248.0,
#   'usd_pledged_real': 5651.0},
#  {'_id': ObjectId('5fc50635d1f608e348e224c9'),
#   'name': "THE YING YANG MURDER MYSTERY'S (Canceled)",
#   'category': 'Webseries',
#   'main_category': 'Film & Video',
#   'goal': 900000.0,
#   'launched': '2014',
#   'pledged': 0.0,
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc50635d1f608e348e224dd'),
#   'name': 'Montgomery Al Concert 5FDP and VOLBEAT',
#   'category': 'Rock',
#   'main_category': 'Music',
#   'goal': 1040000.0,
#   'launched': '2014',
#   'pledged': 0.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc50635d1f608e348e224e3'),
#   'name': 'Wall Scaler',
#   'category': 'Flight',
#   'main_category': 'Technology',
#   'goal': 1000000.0,
#   'launched': '2017',
#   'pledged': 1.0,
#   'state': 'suspended',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 1.0},
#  {'_id': ObjectId('5fc50635d1f608e348e22517'),
#   'name': 'Historic B&B with an in-house French Bakery in Memphis, TN',
#   'category': 'Food',
#   'main_category': 'Food',
#   'goal': 250000.0,
#   'launched': '2016',
#   'pledged': 10100.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 10100.0,
#   'usd_pledged_real': 10100.0},
#  {'_id': ObjectId('5fc50635d1f608e348e22526'),
#   'name': 'Eternal Fate',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'goal': 200000.0,
#   'launched': '2012',
#   'pledged': 12914.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 12914.0,
#   'usd_pledged_real': 12914.0},
#  {'_id': ObjectId('5fc50635d1f608e348e22570'),
#   'name': 'Angelz Landing the Movie',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'goal': 1200000.0,
#   'launched': '2014',
#   'pledged': 356.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 356.0,
#   'usd_pledged_real': 356.0},
#  {'_id': ObjectId('5fc50635d1f608e348e225ee'),
#   'name': 'Morrison Land',
#   'category': 'Movie Theaters',
#   'main_category': 'Film & Video',
#   'goal': 250000.0,
#   'launched': '2014',
#   'pledged': 10.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 10.0,
#   'usd_pledged_real': 10.0},
#  {'_id': ObjectId('5fc50635d1f608e348e22609'),
#   'name': 'Triple Espresso Goes to The Big Apple',
#   'category': 'Theater',
#   'main_category': 'Theater',
#   'goal': 300000.0,
#   'launched': '2013',
#   'pledged': 27581.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 27581.0,
#   'usd_pledged_real': 27581.0},
#  {'_id': ObjectId('5fc50635d1f608e348e2260d'),
#   'name': 'Meetupgolf - Everything Golf, Everything Social',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'goal': 200000.0,
#   'launched': '2016',
#   'pledged': 360.0,
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged': 25.0,
#   'usd_pledged_real': 360.0},
#  {'_id': ObjectId('5fc50635d1f608e348e22615'),
#   'name': 'GunDetect - alerts you when it sees a gun',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'goal': 200000.0,
#   'launched': '2015',
#   'pledged': 43718.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 43718.0,
#   'usd_pledged_real': 43718.0},
#  {'_id': ObjectId('5fc50635d1f608e348e226d5'),
#   'name': 'Take And Seek the Movie',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'goal': 250000.0,
#   'launched': '2013',
#   'pledged': 0.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc50635d1f608e348e226ee'),
#   'name': 'Unsung Story: Tale of the Guardians',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'goal': 600000.0,
#   'launched': '2014',
#   'pledged': 660126.51,
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged': 660126.51,
#   'usd_pledged_real': 660126.51},
#  {'_id': ObjectId('5fc50635d1f608e348e2279b'),
#   'name': 'Harishwar Center for Arts, Spirituality & Sustainability',
#   'category': 'Architecture',
#   'main_category': 'Design',
#   'goal': 1800000.0,
#   'launched': '2016',
#   'pledged': 614.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 614.0,
#   'usd_pledged_real': 614.0},
#  {'_id': ObjectId('5fc50635d1f608e348e227a5'),
#   'name': "The Cancer Patient's Film Project",
#   'category': 'Narrative Film',
#   'main_category': 'Film & Video',
#   'goal': 1500000.0,
#   'launched': '2013',
#   'pledged': 275.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 275.0,
#   'usd_pledged_real': 275.0},
#  {'_id': ObjectId('5fc50635d1f608e348e227c4'),
#   'name': "Small Change: Kids' Financial Life Skills",
#   'category': 'Software',
#   'main_category': 'Technology',
#   'goal': 250000.0,
#   'launched': '2014',
#   'pledged': 3536.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 3536.0,
#   'usd_pledged_real': 3536.0},
#  {'_id': ObjectId('5fc50635d1f608e348e2283b'),
#   'name': 'Save the Williamsburg',
#   'category': 'Public Art',
#   'main_category': 'Art',
#   'goal': 40000000.0,
#   'launched': '2015',
#   'pledged': 21700.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 21700.0,
#   'usd_pledged_real': 21700.0},
#  {'_id': ObjectId('5fc50636d1f608e348e22881'),
#   'name': 'Nephilim, Nazis and the New World Order',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'goal': 500000.0,
#   'launched': '2015',
#   'pledged': 0.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc50636d1f608e348e22891'),
#   'name': 'War At Home',
#   'category': 'Drama',
#   'main_category': 'Film & Video',
#   'goal': 340000.0,
#   'launched': '2015',
#   'pledged': 19328.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 19328.0,
#   'usd_pledged_real': 19328.0},
#  {'_id': ObjectId('5fc50636d1f608e348e22900'),
#   'name': 'North East',
#   'category': 'Drama',
#   'main_category': 'Film & Video',
#   'goal': 250000.0,
#   'launched': '2017',
#   'pledged': 2.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 2.0},
#  {'_id': ObjectId('5fc50636d1f608e348e2291f'),
#   'name': 'The Great Pyramid, Project USA',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'goal': 300000.0,
#   'launched': '2014',
#   'pledged': 35.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 35.0,
#   'usd_pledged_real': 35.0},
#  {'_id': ObjectId('5fc50636d1f608e348e2295c'),
#   'name': 'Time travel app',
#   'category': 'Apps',
#   'main_category': 'Technology',
#   'goal': 375000.0,
#   'launched': '2017',
#   'pledged': 135.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 10.0,
#   'usd_pledged_real': 135.0},
#  {'_id': ObjectId('5fc50636d1f608e348e229af'),
#   'name': 'Honolulu Haze (Canceled)',
#   'category': 'Narrative Film',
#   'main_category': 'Film & Video',
#   'goal': 500000.0,
#   'launched': '2013',
#   'pledged': 70.0,
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged': 70.0,
#   'usd_pledged_real': 70.0},
#  {'_id': ObjectId('5fc50636d1f608e348e22a52'),
#   'name': 'Motor Sports Mailboxes',
#   'category': 'Crafts',
#   'main_category': 'Crafts',
#   'goal': 600000.0,
#   'launched': '2014',
#   'pledged': 200.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 200.0,
#   'usd_pledged_real': 200.0},
#  {'_id': ObjectId('5fc50636d1f608e348e22ae3'),
#   'name': 'Patented MoveNetic Lock - New Post 9-11 Locking Method',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'goal': 350000.0,
#   'launched': '2014',
#   'pledged': 60.0,
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged': 60.0,
#   'usd_pledged_real': 60.0},
#  {'_id': ObjectId('5fc50636d1f608e348e22b73'),
#   'name': 'Where Is the Love? (A Dedication to Love) (Canceled)',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'goal': 200000.0,
#   'launched': '2012',
#   'pledged': 5.0,
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged': 5.0,
#   'usd_pledged_real': 5.0},
#  {'_id': ObjectId('5fc50636d1f608e348e22bae'),
#   'name': 'Love Over A Million Years',
#   'category': 'Movie Theaters',
#   'main_category': 'Film & Video',
#   'goal': 200000.0,
#   'launched': '2015',
#   'pledged': 0.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc50636d1f608e348e22c3d'),
#   'name': 'Hoverboard: The Next Evolution in Personal Electric Mobility',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'goal': 500000.0,
#   'launched': '2015',
#   'pledged': 257275.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 257275.0,
#   'usd_pledged_real': 257275.0},
#  {'_id': ObjectId('5fc50636d1f608e348e22c86'),
#   'name': 'Make A South African Feature Film! (Canceled)',
#   'category': 'Narrative Film',
#   'main_category': 'Film & Video',
#   'goal': 2500000.0,
#   'launched': '2011',
#   'pledged': 0.0,
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc50636d1f608e348e22d27'),
#   'name': 'Feature-Length Movie: Secret of the Missing Grave',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'goal': 10000000.0,
#   'launched': '2013',
#   'pledged': 11975.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 11975.0,
#   'usd_pledged_real': 11975.0},
#  {'_id': ObjectId('5fc50636d1f608e348e22d56'),
#   'name': "Hey Chicago  It's all about you!",
#   'category': 'Design',
#   'main_category': 'Design',
#   'goal': 380000.0,
#   'launched': '2015',
#   'pledged': 950.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 950.0,
#   'usd_pledged_real': 950.0},
#  {'_id': ObjectId('5fc50636d1f608e348e22d98'),
#   'name': 'All Points Bulletin (APB): Vendetta',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'goal': 300000.0,
#   'launched': '2013',
#   'pledged': 27614.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 27614.0,
#   'usd_pledged_real': 27614.0},
#  {'_id': ObjectId('5fc50636d1f608e348e22de2'),
#   'name': 'As Cine On TV',
#   'category': 'Translations',
#   'main_category': 'Publishing',
#   'goal': 2000000.0,
#   'launched': '2017',
#   'pledged': 192.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 50.0,
#   'usd_pledged_real': 192.0},
#  {'_id': ObjectId('5fc50636d1f608e348e22ded'),
#   'name': 'The Hendrix Keg - Carbonated, Fresh, Craft Beer on Tap',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'goal': 300000.0,
#   'launched': '2017',
#   'pledged': 48307.0,
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged': 9302.0,
#   'usd_pledged_real': 48307.0},
#  {'_id': ObjectId('5fc50636d1f608e348e22e8b'),
#   'name': 'Supporting Disaster Relief through the Power of Music',
#   'category': 'Classical Music',
#   'main_category': 'Music',
#   'goal': 200000.0,
#   'launched': '2017',
#   'pledged': 560.0,
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 560.0},
#  {'_id': ObjectId('5fc50636d1f608e348e22f06'),
#   'name': "#TINYHUMANSGETTIN'FRESH! Help a Veteran's Wife's Company!",
#   'category': 'Food',
#   'main_category': 'Food',
#   'goal': 200000.0,
#   'launched': '2014',
#   'pledged': 106.0,
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged': 106.0,
#   'usd_pledged_real': 106.0},
#  {'_id': ObjectId('5fc50636d1f608e348e22f11'),
#   'name': 'On The Wings Of A Miracle - An Animated Family Film',
#   'category': 'Animation',
#   'main_category': 'Film & Video',
#   'goal': 200000.0,
#   'launched': '2012',
#   'pledged': 4135.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 4135.0,
#   'usd_pledged_real': 4135.0},
#  {'_id': ObjectId('5fc50636d1f608e348e22f41'),
#   'name': 'Love Gives Hope Art Gallery for Cultural Diversity!',
#   'category': 'Art',
#   'main_category': 'Art',
#   'goal': 300000.0,
#   'launched': '2017',
#   'pledged': 1.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 1.0},
#  {'_id': ObjectId('5fc50636d1f608e348e22f61'),
#   'name': 'The "Get Home Now" Device',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'goal': 250000.0,
#   'launched': '2014',
#   'pledged': 1.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 1.0,
#   'usd_pledged_real': 1.0},
#  {'_id': ObjectId('5fc50637d1f608e348e2302b'),
#   'name': 'In Pursuit of Passion - Travel Television Series',
#   'category': 'Television',
#   'main_category': 'Film & Video',
#   'goal': 280000.0,
#   'launched': '2016',
#   'pledged': 100.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 100.0,
#   'usd_pledged_real': 100.0},
#  {'_id': ObjectId('5fc50637d1f608e348e23059'),
#   'name': 'Welcome to the Wonderful World of AIDS',
#   'category': 'Thrillers',
#   'main_category': 'Film & Video',
#   'goal': 500000.0,
#   'launched': '2014',
#   'pledged': 2827.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 2827.0,
#   'usd_pledged_real': 2827.0},
#  {'_id': ObjectId('5fc50637d1f608e348e23076'),
#   'name': 'The Homeless art Studio (pic from AP) FUCKING HELP OUT',
#   'category': 'Public Art',
#   'main_category': 'Art',
#   'goal': 500000.0,
#   'launched': '2016',
#   'pledged': 116.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 116.0,
#   'usd_pledged_real': 116.0},
#  {'_id': ObjectId('5fc50637d1f608e348e230b4'),
#   'name': 'From Dawson to Jackson Vineyards',
#   'category': 'Farms',
#   'main_category': 'Food',
#   'goal': 1000000.0,
#   'launched': '2014',
#   'pledged': 25.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 25.0,
#   'usd_pledged_real': 25.0},
#  {'_id': ObjectId('5fc50637d1f608e348e2313f'),
#   'name': 'Make clear ice cubes at home.',
#   'category': 'Drinks',
#   'main_category': 'Food',
#   'goal': 200000.0,
#   'launched': '2015',
#   'pledged': 15.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 15.0,
#   'usd_pledged_real': 15.0},
#  {'_id': ObjectId('5fc50637d1f608e348e231e3'),
#   'name': 'COUCH DIARIES',
#   'category': 'Publishing',
#   'main_category': 'Publishing',
#   'goal': 200000.0,
#   'launched': '2013',
#   'pledged': 0.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc50637d1f608e348e2325b'),
#   'name': 'Art Story',
#   'category': 'Animation',
#   'main_category': 'Film & Video',
#   'goal': 350000.0,
#   'launched': '2013',
#   'pledged': 365670.0,
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged': 365670.0,
#   'usd_pledged_real': 365670.0},
#  {'_id': ObjectId('5fc50637d1f608e348e2329a'),
#   'name': 'My a MAZING Academic Profile',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'goal': 2852666.0,
#   'launched': '2014',
#   'pledged': 130.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 130.0,
#   'usd_pledged_real': 130.0},
#  {'_id': ObjectId('5fc50637d1f608e348e2329d'),
#   'name': 'Untold Universe (Canceled)',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'goal': 200000.0,
#   'launched': '2014',
#   'pledged': 5981.01,
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged': 5981.01,
#   'usd_pledged_real': 5981.01},
#  {'_id': ObjectId('5fc50637d1f608e348e232bc'),
#   'name': 'The Hill (Canceled)',
#   'category': 'Festivals',
#   'main_category': 'Theater',
#   'goal': 1575000.0,
#   'launched': '2014',
#   'pledged': 203.0,
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged': 203.0,
#   'usd_pledged_real': 203.0},
#  {'_id': ObjectId('5fc50637d1f608e348e232cd'),
#   'name': 'Sports Cards Unlimited (Canceled)',
#   'category': 'Playing Cards',
#   'main_category': 'Games',
#   'goal': 400000.0,
#   'launched': '2015',
#   'pledged': 0.0,
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc50637d1f608e348e23328'),
#   'name': 'Pushup Extreme. (Canceled)',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'goal': 215000.0,
#   'launched': '2013',
#   'pledged': 9748.0,
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged': 9748.0,
#   'usd_pledged_real': 9748.0},
#  {'_id': ObjectId('5fc50637d1f608e348e233d4'),
#   'name': 'Everyday Dreamers Living in the Beautiful Struggle',
#   'category': 'Hip-Hop',
#   'main_category': 'Music',
#   'goal': 3500000.0,
#   'launched': '2016',
#   'pledged': 11.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 11.0},
#  {'_id': ObjectId('5fc50637d1f608e348e233fb'),
#   'name': 'Top Side Dinner Show! Eat, watch, party, and always enjoy!',
#   'category': 'Movie Theaters',
#   'main_category': 'Film & Video',
#   'goal': 425000.0,
#   'launched': '2015',
#   'pledged': 0.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc50637d1f608e348e23404'),
#   'name': 'The Real Kratos - Epic Action Film',
#   'category': 'Shorts',
#   'main_category': 'Film & Video',
#   'goal': 295000.0,
#   'launched': '2013',
#   'pledged': 251.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 251.0,
#   'usd_pledged_real': 251.0},
#  {'_id': ObjectId('5fc50637d1f608e348e23409'),
#   'name': 'My Russian Kitchen: Love Story',
#   'category': 'Food',
#   'main_category': 'Food',
#   'goal': 495000.0,
#   'launched': '2013',
#   'pledged': 150.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 150.0,
#   'usd_pledged_real': 150.0},
#  {'_id': ObjectId('5fc50637d1f608e348e2342b'),
#   'name': 'The Fuffr Touch Case ï¿½ Multitouch Outside Your Smartphone',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'goal': 250000.0,
#   'launched': '2014',
#   'pledged': 11883.0,
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged': 11883.0,
#   'usd_pledged_real': 11883.0},
#  {'_id': ObjectId('5fc50637d1f608e348e2347f'),
#   'name': "Joe N'Mo To Go!",
#   'category': 'Food Trucks',
#   'main_category': 'Food',
#   'goal': 400000.0,
#   'launched': '2016',
#   'pledged': 15.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 10.0,
#   'usd_pledged_real': 15.0},
#  {'_id': ObjectId('5fc50637d1f608e348e23486'),
#   'name': "H-Hour: World's Elite",
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'goal': 200000.0,
#   'launched': '2013',
#   'pledged': 252662.28,
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged': 252662.28,
#   'usd_pledged_real': 252662.28},
#  {'_id': ObjectId('5fc50637d1f608e348e23490'),
#   'name': 'Free the sound',
#   'category': 'Music',
#   'main_category': 'Music',
#   'goal': 200000.0,
#   'launched': '2016',
#   'pledged': 0.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc50637d1f608e348e234b0'),
#   'name': 'Japanese Fighting Fish & Japanese Fighting Fish Hold Em',
#   'category': 'Playing Cards',
#   'main_category': 'Games',
#   'goal': 500000.0,
#   'launched': '2015',
#   'pledged': 10.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 10.0,
# ...
#   'name': 'The Prophet Chronicles: Redemption - Pre-Production',
#   'category': 'Narrative Film',
#   'main_category': 'Film & Video',
#   'goal': 500000.0,
#   'launched': '2011',
#   'pledged': 0.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc50680d1f608e348e40c03'),
#   'name': 'Zig',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'goal': 250000.0,
#   'launched': '2015',
#   'pledged': 122626.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 122626.0,
#   'usd_pledged_real': 122626.0},
#  {'_id': ObjectId('5fc50680d1f608e348e40d1c'),
#   'name': 'MindRider: A Bike Helmet That Maps Your Best Route',
#   'category': 'Wearables',
#   'main_category': 'Technology',
#   'goal': 200000.0,
#   'launched': '2014',
#   'pledged': 16486.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 16486.0,
#   'usd_pledged_real': 16486.0},
#  {'_id': ObjectId('5fc50680d1f608e348e40d2c'),
#   'name': 'LifeCool - Amazing lifesaving cooler for all boats!',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'goal': 400000.0,
#   'launched': '2015',
#   'pledged': 22191.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 22191.0,
#   'usd_pledged_real': 22191.0},
#  {'_id': ObjectId('5fc50680d1f608e348e40d43'),
#   'name': 'The Sanctuary: Tiny House Community',
#   'category': 'Architecture',
#   'main_category': 'Design',
#   'goal': 200000.0,
#   'launched': '2015',
#   'pledged': 10.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 10.0,
#   'usd_pledged_real': 10.0},
#  {'_id': ObjectId('5fc50680d1f608e348e40dca'),
#   'name': "SPLIT: The World's Only Earbuds with no Strings Attached",
#   'category': 'Design',
#   'main_category': 'Design',
#   'goal': 435000.0,
#   'launched': '2013',
#   'pledged': 61537.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 61537.0,
#   'usd_pledged_real': 61537.0},
#  {'_id': ObjectId('5fc50680d1f608e348e40e91'),
#   'name': 'FILM w/ THORA BIRCH, HEATHER MATARAZZO, JENNIFER ELISE COX',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'goal': 5000000.0,
#   'launched': '2013',
#   'pledged': 243.47,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 243.47,
#   'usd_pledged_real': 243.47},
#  {'_id': ObjectId('5fc50680d1f608e348e40ebe'),
#   'name': 'BIP Records, support the movement and it will support you.',
#   'category': 'Music',
#   'main_category': 'Music',
#   'goal': 250000.0,
#   'launched': '2015',
#   'pledged': 0.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc50680d1f608e348e40f07'),
#   'name': 'INDIA',
#   'category': 'Action',
#   'main_category': 'Film & Video',
#   'goal': 200000.0,
#   'launched': '2015',
#   'pledged': 0.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc50680d1f608e348e40fe5'),
#   'name': 'Environmentally Safe Storm Drains + Parking Lots',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'goal': 2500000.0,
#   'launched': '2016',
#   'pledged': 0.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc50680d1f608e348e40ff6'),
#   'name': 'All Race Matters! (Canceled)',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'goal': 250000.0,
#   'launched': '2016',
#   'pledged': 0.0,
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc50680d1f608e348e41038'),
#   'name': 'Petcube Bites + Petcube Play: Treat & Care for Pets Remotely',
#   'category': 'Gadgets',
#   'main_category': 'Technology',
#   'goal': 200000.0,
#   'launched': '2016',
#   'pledged': 319193.0,
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged': 18208.0,
#   'usd_pledged_real': 319193.0},
#  {'_id': ObjectId('5fc50680d1f608e348e4106f'),
#   'name': 'Top-down Action RPG, Indie Developed',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'goal': 200000.0,
#   'launched': '2016',
#   'pledged': 560.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 500.0,
#   'usd_pledged_real': 560.0},
#  {'_id': ObjectId('5fc50680d1f608e348e410a8'),
#   'name': 'Pet Bottle Bowl',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'goal': 200000.0,
#   'launched': '2015',
#   'pledged': 425.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 425.0,
#   'usd_pledged_real': 425.0},
#  {'_id': ObjectId('5fc50680d1f608e348e410b6'),
#   'name': 'Recording Studio',
#   'category': 'Music',
#   'main_category': 'Music',
#   'goal': 300000.0,
#   'launched': '2017',
#   'pledged': 0.0,
#   'state': 'live',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc50680d1f608e348e410c2'),
#   'name': 'Candy store & Deli in Clearwater Beach',
#   'category': 'Restaurants',
#   'main_category': 'Food',
#   'goal': 500000.0,
#   'launched': '2016',
#   'pledged': 1.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 1.0,
#   'usd_pledged_real': 1.0},
#  {'_id': ObjectId('5fc50680d1f608e348e4119b'),
#   'name': '"FRIGHT PLAN"',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'goal': 345000.0,
#   'launched': '2012',
#   'pledged': 0.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc50680d1f608e348e411bd'),
#   'name': 'Rebuild Enzo Ferrari',
#   'category': 'Crafts',
#   'main_category': 'Crafts',
#   'goal': 2500000.0,
#   'launched': '2014',
#   'pledged': 0.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc50680d1f608e348e411ca'),
#   'name': 'Electric Vehicle Self Charging system - Drive and Charge',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'goal': 300000.0,
#   'launched': '2014',
#   'pledged': 124.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 124.0,
#   'usd_pledged_real': 124.0},
#  {'_id': ObjectId('5fc50680d1f608e348e411de'),
#   'name': 'Sweet Mara film project',
#   'category': 'Narrative Film',
#   'main_category': 'Film & Video',
#   'goal': 1000000.0,
#   'launched': '2012',
#   'pledged': 12512.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 12512.0,
#   'usd_pledged_real': 12512.0},
#  {'_id': ObjectId('5fc50680d1f608e348e41208'),
#   'name': 'Calypso Music Festival',
#   'category': 'Electronic Music',
#   'main_category': 'Music',
#   'goal': 250000.0,
#   'launched': '2015',
#   'pledged': 0.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc50681d1f608e348e41284'),
#   'name': 'Nomasoak-The first truly portable hot tub',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'goal': 350000.0,
#   'launched': '2014',
#   'pledged': 8593.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 8593.0,
#   'usd_pledged_real': 8593.0},
#  {'_id': ObjectId('5fc50681d1f608e348e4128b'),
#   'name': "Salvators' Winery & Restaurant",
#   'category': 'Food',
#   'main_category': 'Food',
#   'goal': 3500000.0,
#   'launched': '2012',
#   'pledged': 125.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 125.0,
#   'usd_pledged_real': 125.0},
#  {'_id': ObjectId('5fc50681d1f608e348e412de'),
#   'name': 'Mariner Farms: local, closed loop, organic food production.',
#   'category': 'Farms',
#   'main_category': 'Food',
#   'goal': 250000.0,
#   'launched': '2014',
#   'pledged': 11.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 11.0,
#   'usd_pledged_real': 11.0},
#  {'_id': ObjectId('5fc50681d1f608e348e4135e'),
#   'name': 'GetActive',
#   'category': 'Apps',
#   'main_category': 'Technology',
#   'goal': 210000.0,
#   'launched': '2015',
#   'pledged': 1225.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 1225.0,
#   'usd_pledged_real': 1225.0},
#  {'_id': ObjectId('5fc50681d1f608e348e41362'),
#   'name': 'Walk of Fame',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'goal': 200000.0,
#   'launched': '2013',
#   'pledged': 4625.29,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 4625.29,
#   'usd_pledged_real': 4625.29},
#  {'_id': ObjectId('5fc50681d1f608e348e4137f'),
#   'name': 'Somewhere in Time (Canceled)',
#   'category': 'Restaurants',
#   'main_category': 'Food',
#   'goal': 300000.0,
#   'launched': '2015',
#   'pledged': 0.0,
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc50681d1f608e348e413a3'),
#   'name': 'Larceny Lock: Make Your Door Kick-in Proof',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'goal': 500000.0,
#   'launched': '2015',
#   'pledged': 156.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 156.0,
#   'usd_pledged_real': 156.0},
#  {'_id': ObjectId('5fc50681d1f608e348e413a8'),
#   'name': 'Helpeddle',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'goal': 210000.0,
#   'launched': '2015',
#   'pledged': 46.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 46.0,
#   'usd_pledged_real': 46.0},
#  {'_id': ObjectId('5fc50681d1f608e348e413b4'),
#   'name': 'Ceramic Pie Studios',
#   'category': 'Ceramics',
#   'main_category': 'Art',
#   'goal': 325000.0,
#   'launched': '2017',
#   'pledged': 190.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 50.0,
#   'usd_pledged_real': 190.0},
#  {'_id': ObjectId('5fc50681d1f608e348e413e6'),
#   'name': 'Endless Dreams Pillow / Adjustable pillow',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'goal': 650000.0,
#   'launched': '2016',
#   'pledged': 21.0,
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged': 20.0,
#   'usd_pledged_real': 21.0},
#  {'_id': ObjectId('5fc50681d1f608e348e413e8'),
#   'name': '"let go of my eggo - Morning Show"',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'goal': 200000.0,
#   'launched': '2016',
#   'pledged': 1000.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 1000.0},
#  {'_id': ObjectId('5fc50681d1f608e348e4141f'),
#   'name': 'Salt Bill Home Beer Kit',
#   'category': 'Drinks',
#   'main_category': 'Food',
#   'goal': 425000.0,
#   'launched': '2017',
#   'pledged': 470.0,
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged': 420.0,
#   'usd_pledged_real': 470.0},
#  {'_id': ObjectId('5fc50681d1f608e348e414d1'),
#   'name': 'Kingdom of Oberon',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'goal': 400000.0,
#   'launched': '2014',
#   'pledged': 1.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 1.0,
#   'usd_pledged_real': 1.0},
#  {'_id': ObjectId('5fc50681d1f608e348e4152a'),
#   'name': 'Shark Tooth Edger',
#   'category': 'Gadgets',
#   'main_category': 'Technology',
#   'goal': 475000.0,
#   'launched': '2016',
#   'pledged': 101.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 101.0},
#  {'_id': ObjectId('5fc50681d1f608e348e41539'),
#   'name': 'Bazadee Sports (Canceled)',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'goal': 2000000.0,
#   'launched': '2015',
#   'pledged': 10.0,
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged': 10.0,
#   'usd_pledged_real': 10.0},
#  {'_id': ObjectId('5fc50681d1f608e348e4153d'),
#   'name': 'SANTA MARIA: THE FIRST VOYAGE',
#   'category': 'Science Fiction',
#   'main_category': 'Film & Video',
#   'goal': 700000.0,
#   'launched': '2014',
#   'pledged': 10.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 10.0,
#   'usd_pledged_real': 10.0},
#  {'_id': ObjectId('5fc50681d1f608e348e41568'),
#   'name': 'Help us fund a new hobby shop for everyone',
#   'category': 'Games',
#   'main_category': 'Games',
#   'goal': 276855.0,
#   'launched': '2014',
#   'pledged': 5.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 5.0,
#   'usd_pledged_real': 5.0},
#  {'_id': ObjectId('5fc50681d1f608e348e41698'),
#   'name': 'Earth Sheltered Homes Nightly Rental Project',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'goal': 300000.0,
#   'launched': '2014',
#   'pledged': 3.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 3.0,
#   'usd_pledged_real': 3.0},
#  {'_id': ObjectId('5fc50681d1f608e348e4169c'),
#   'name': 'Trail Of Fears Haunted House',
#   'category': 'Theater',
#   'main_category': 'Theater',
#   'goal': 500000.0,
#   'launched': '2015',
#   'pledged': 2.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 2.0,
#   'usd_pledged_real': 2.0},
#  {'_id': ObjectId('5fc50681d1f608e348e4171b'),
#   'name': 'Miss Wisenheimer and the Aliens',
#   'category': 'Science Fiction',
#   'main_category': 'Film & Video',
#   'goal': 822996.0,
#   'launched': '2016',
#   'pledged': 11890.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 11890.0,
#   'usd_pledged_real': 11890.0},
#  {'_id': ObjectId('5fc50681d1f608e348e4171d'),
#   'name': 'The First Iditarod: The Amazing Dogs & Their Mushers',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'goal': 235000.0,
#   'launched': '2017',
#   'pledged': 4645.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 4645.0},
#  {'_id': ObjectId('5fc50681d1f608e348e4177c'),
#   'name': "sonoro Cubo: World's First All-In-One SmartHome Audio System",
#   'category': 'Design',
#   'main_category': 'Design',
#   'goal': 250000.0,
#   'launched': '2016',
#   'pledged': 2150.0,
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged': 2150.0,
#   'usd_pledged_real': 2150.0},
#  {'_id': ObjectId('5fc50681d1f608e348e41822'),
#   'name': '5 Degrees of Separation (Canceled)',
#   'category': 'Nonfiction',
#   'main_category': 'Publishing',
#   'goal': 1000000.0,
#   'launched': '2012',
#   'pledged': 0.0,
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc50681d1f608e348e4182e'),
#   'name': 'Beyond the Pillowed Bed',
#   'category': 'Fashion',
#   'main_category': 'Fashion',
#   'goal': 250000.0,
#   'launched': '2011',
#   'pledged': 120.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 120.0,
#   'usd_pledged_real': 120.0},
#  {'_id': ObjectId('5fc50681d1f608e348e4183c'),
#   'name': 'Camp Oak Hallows - A Wizarding World Experience',
#   'category': 'Immersive',
#   'main_category': 'Theater',
#   'goal': 1000000.0,
#   'launched': '2016',
#   'pledged': 75.0,
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged': 50.0,
#   'usd_pledged_real': 75.0},
#  {'_id': ObjectId('5fc50681d1f608e348e418ab'),
#   'name': 'Conscious Conscience',
#   'category': 'Drama',
#   'main_category': 'Film & Video',
#   'goal': 1000000.0,
#   'launched': '2015',
#   'pledged': 0.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc50681d1f608e348e418cf'),
#   'name': 'Theory of the Evolution of Mind',
#   'category': 'Academic',
#   'main_category': 'Publishing',
#   'goal': 200000.0,
#   'launched': '2015',
#   'pledged': 9010.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 9010.0,
#   'usd_pledged_real': 9010.0},
#  {'_id': ObjectId('5fc50681d1f608e348e41908'),
#   'name': 'TeenEdTech',
#   'category': 'Software',
#   'main_category': 'Technology',
#   'goal': 200000.0,
#   'launched': '2016',
#   'pledged': 2.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 2.0,
#   'usd_pledged_real': 2.0},
#  {'_id': ObjectId('5fc50681d1f608e348e41985'),
#   'name': 'Fund the Freedom to Bear Arms',
#   'category': 'Restaurants',
#   'main_category': 'Food',
#   'goal': 200000.0,
#   'launched': '2014',
#   'pledged': 50.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 50.0,
#   'usd_pledged_real': 50.0},
#  {'_id': ObjectId('5fc50681d1f608e348e4199a'),
#   'name': 'King of the Dead - A Horror / Comedy Movie',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'goal': 250000.0,
#   'launched': '2012',
#   'pledged': 55.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 55.0,
#   'usd_pledged_real': 55.0},
#  {'_id': ObjectId('5fc50681d1f608e348e419c3'),
#   'name': 'The Brandon Lee Movie Project',
#   'category': 'Narrative Film',
#   'main_category': 'Film & Video',
#   'goal': 200000.0,
#   'launched': '2013',
#   'pledged': 2338.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 2338.0,
#   'usd_pledged_real': 2338.0},
#  ...]

# %% [markdown]
# ## Question 6

# %%
#to be able to search through the name
collection.create_index([("name",  "text")])
# Out:
# 'name_text'

# %%
cur = collection.count_documents({ "$text": { "$search": "Sport" } })
print(cur)
# Out:
# 318
